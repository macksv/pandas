# %%
from sqlalchemy import create_engine
import pandas as pd
import configparser
import psycopg2

# %%
# get data from configuration file
config = configparser.ConfigParser()
try:
    config.read('ETLDemo.ini')
except Exception as e:
    print('could not read configuration file:' + str(e))
    sys.exit()

# %%
# read settings from configuration file
server = config['CONFIG']['server']
database = config['CONFIG']['database']
user = config['CONFIG']['user']
password = config['CONFIG']['password']

# %%
#engine = create_engine('postgresql://test_user1:abc123@localhost:5432/test_db1')
engine = create_engine('postgresql://' + user + ':' + password + '@' + server + ':5432/' + database)

# %%
test_cases_df = pd.read_csv('test_cases.csv')

# %%
test_cases_df
# Out:
#    trans_key  Field_1  Field_2  Field_3  Result_value  \
# 0        101    100.0     45.0     72.0        237.00
# 1        102    200.0     20.0     41.0        443.50
# 2        105    333.2     55.6     88.9        123.80
# 3        106    111.0    444.0    333.0        888.00
# 4        200    233.0    553.0    436.0        783.00
# 5        222    437.0    889.0    554.0        453.65
# 6        245    332.0    436.0    663.0        576.89
#
#                                                Query
# 0  select result_value from dummy_results where t...
# 1  select result_value from dummy_results where t...
# 2  select result_value from dummy_results where t...
# 3  select result_value from dummy_results where t...
# 4  select result_value from dummy_results2 where ...
# 5  select result_value from dummy_results2 where ...
# 6  select result_value from dummy_results2 where ...

# %%
test_cases_df = test_cases_df.set_index('trans_key')
test_cases_df
# Out:
#            Field_1  Field_2  Field_3  Result_value  \
# trans_key
# 101          100.0     45.0     72.0        237.00
# 102          200.0     20.0     41.0        443.50
# 105          333.2     55.6     88.9        123.80
# 106          111.0    444.0    333.0        888.00
# 200          233.0    553.0    436.0        783.00
# 222          437.0    889.0    554.0        453.65
# 245          332.0    436.0    663.0        576.89
#
#                                                        Query
# trans_key
# 101        select result_value from dummy_results where t...
# 102        select result_value from dummy_results where t...
# 105        select result_value from dummy_results where t...
# 106        select result_value from dummy_results where t...
# 200        select result_value from dummy_results2 where ...
# 222        select result_value from dummy_results2 where ...
# 245        select result_value from dummy_results2 where ...

# %%
test_cases_df['Query']
# Out:
# trans_key
# 101    select result_value from dummy_results where t...
# 102    select result_value from dummy_results where t...
# 105    select result_value from dummy_results where t...
# 106    select result_value from dummy_results where t...
# 200    select result_value from dummy_results2 where ...
# 222    select result_value from dummy_results2 where ...
# 245    select result_value from dummy_results2 where ...
# Name: Query, dtype: object

# %%
db_result_df = pd.DataFrame(columns = ['Key', 'computed_value'])

# %%
# Connect to PostgreSQL server
dbConnection    = engine.connect();

# %%
for ind in test_cases_df.index:
    query_df = pd.read_sql(test_cases_df.loc[ind, 'Query'], dbConnection);
    
    if (len(query_df.index) != 0):
        
        db_result_df = db_result_df.append({'Key': ind, 'computed_value': query_df['result_value'].values[0]}, ignore_index = True)
        #test_cases_df.loc[ind, 'computed_value'] = query_df['result_value']
        print(query_df['result_value'].values[0])
    else:
        print("DF is Empty !!!")
# Out:
# 237.0
# 123.45
# DF is Empty !!!
# DF is Empty !!!
# 783.0
# 453.65
# 664.0

# %%
db_result_df
# Out:
#      Key  computed_value
# 0  101.0          237.00
# 1  102.0          123.45
# 2  200.0          783.00
# 3  222.0          453.65
# 4  245.0          664.00

# %%
db_result_df = db_result_df.set_index('Key')
db_result_df
# Out:
#        computed_value
# Key
# 101.0          237.00
# 102.0          123.45
# 200.0          783.00
# 222.0          453.65
# 245.0          664.00

# %%
combined_df = pd.concat([test_cases_df, db_result_df], axis=1)

# %%
combined_df
# Out:
#        Field_1  Field_2  Field_3  Result_value  \
# 101.0    100.0     45.0     72.0        237.00
# 102.0    200.0     20.0     41.0        443.50
# 105.0    333.2     55.6     88.9        123.80
# 106.0    111.0    444.0    333.0        888.00
# 200.0    233.0    553.0    436.0        783.00
# 222.0    437.0    889.0    554.0        453.65
# 245.0    332.0    436.0    663.0        576.89
#
#                                                    Query  computed_value
# 101.0  select result_value from dummy_results where t...          237.00
# 102.0  select result_value from dummy_results where t...          123.45
# 105.0  select result_value from dummy_results where t...             NaN
# 106.0  select result_value from dummy_results where t...             NaN
# 200.0  select result_value from dummy_results2 where ...          783.00
# 222.0  select result_value from dummy_results2 where ...          453.65
# 245.0  select result_value from dummy_results2 where ...          664.00

# %%
test_cases_df = test_cases_df.join(db_result_df)

# %%
test_cases_df
# Out:
#            Field_1  Field_2  Field_3  Result_value  \
# trans_key
# 101          100.0     45.0     72.0        237.00
# 102          200.0     20.0     41.0        443.50
# 105          333.2     55.6     88.9        123.80
# 106          111.0    444.0    333.0        888.00
# 200          233.0    553.0    436.0        783.00
# 222          437.0    889.0    554.0        453.65
# 245          332.0    436.0    663.0        576.89
#
#                                                        Query  computed_value
# trans_key
# 101        select result_value from dummy_results where t...          237.00
# 102        select result_value from dummy_results where t...          123.45
# 105        select result_value from dummy_results where t...             NaN
# 106        select result_value from dummy_results where t...             NaN
# 200        select result_value from dummy_results2 where ...          783.00
# 222        select result_value from dummy_results2 where ...          453.65
# 245        select result_value from dummy_results2 where ...          664.00

# %%
import numpy as np
test_cases_df['Pass_Fail'] = np.where(test_cases_df['Result_value'] == test_cases_df['computed_value'], 'Pass', 'Fail')

# %%
test_cases_df
# Out:
#            Field_1  Field_2  Field_3  Result_value  \
# trans_key
# 101          100.0     45.0     72.0        237.00
# 102          200.0     20.0     41.0        443.50
# 105          333.2     55.6     88.9        123.80
# 106          111.0    444.0    333.0        888.00
# 200          233.0    553.0    436.0        783.00
# 222          437.0    889.0    554.0        453.65
# 245          332.0    436.0    663.0        576.89
#
#                                                        Query  computed_value  \
# trans_key
# 101        select result_value from dummy_results where t...          237.00
# 102        select result_value from dummy_results where t...          123.45
# 105        select result_value from dummy_results where t...             NaN
# 106        select result_value from dummy_results where t...             NaN
# 200        select result_value from dummy_results2 where ...          783.00
# 222        select result_value from dummy_results2 where ...          453.65
# 245        select result_value from dummy_results2 where ...          664.00
#
#           Pass_Fail
# trans_key
# 101            Pass
# 102            Fail
# 105            Fail
# 106            Fail
# 200            Pass
# 222            Pass
# 245            Fail
